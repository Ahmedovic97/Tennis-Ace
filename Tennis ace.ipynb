# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('tennis_stats.csv')
df.head()
# Out:
#                  Player  Year  FirstServe  FirstServePointsWon  \
# 0           Pedro Sousa  2016        0.88                 0.50
# 1       Roman Safiullin  2017        0.84                 0.62
# 2           Pedro Sousa  2017        0.83                 0.60
# 3   Rogerio Dutra Silva  2010        0.83                 0.64
# 4  Daniel Gimeno-Traver  2017        0.81                 0.54
#
#    FirstServeReturnPointsWon  SecondServePointsWon  \
# 0                       0.38                  0.50
# 1                       0.26                  0.33
# 2                       0.28                  0.53
# 3                       0.34                  0.59
# 4                       0.00                  0.33
#
#    SecondServeReturnPointsWon  Aces  BreakPointsConverted  BreakPointsFaced  \
# 0                        0.39     0                  0.14                 7
# 1                        0.07     7                  0.00                 7
# ...

# %% [markdown]
# ## Exploratory analysis

# %%
plt.scatter(df[['FirstServe']], df[['Winnings']], alpha=0.4)
plt.show()

# %%
plt.scatter(df[['FirstServePointsWon']], df[['Winnings']], alpha=0.4)
plt.show()

# %%
plt.scatter(df[['BreakPointsConverted']], df[['Winnings']],alpha=0.4)
plt.show()

# %%
plt.scatter(df[['BreakPointsOpportunities']], df[['Winnings']], alpha=0.4)
plt.show()

# %%
plt.scatter(df[['Aces']], df[['Winnings']], alpha=0.4)
plt.show()

# %% [markdown]
# ## single feature linear regressions

# %%
feature1 = df[['BreakPointsConverted']]

winnings = df[['Winnings']]

feature1_train, feature1_test, winnings_train, winnings_test = train_test_split(feature1, winnings, train_size=0.8)

model = LinearRegression()
model.fit(feature1_train, winnings_train)
print('Predicting winnings with BreakPoints converted:', model.score(feature1_test, winnings_test))

prediction1 = model.predict(feature1_test)
plt.scatter(winnings_test, prediction1, alpha=0.4)
plt.xlabel('Actual Winnings', fontsize=12)
plt.ylabel('Predicted Winnings', fontsize=12)
plt.title('Actual Winnings vs Predicted Winnings using Breakpoint Converted Feature')
plt.show()
# Out:
# Predicting winnings with BreakPoints converted: 0.007784738259646207

# %%
feature2 = df[['FirstServePointsWon']]

winnings = df[['Winnings']]

feature2_train, feature2_test, winnings_train, winnings_test = train_test_split(feature2, winnings, train_size=0.8)

model = LinearRegression()
model.fit(feature2_train, winnings_train)
print('Predicting winnings with FirstServePointsWon:', model.score(feature2_test, winnings_test))

prediction2 = model.predict(feature2_test)
plt.scatter(winnings_test, prediction2, alpha=0.4)
plt.xlabel('Actual Winnings', fontsize=12)
plt.ylabel('Predicted Winnings', fontsize=12)
plt.title('Actual Winnings vs Predicted Winnings using FirstServePointsWon Feature')
plt.show()
# Out:
# Predicting winnings with FirstServePointsWon: 0.1669757514415845

# %%
feature3 = df[['BreakPointsOpportunities']]

winnings = df[['Winnings']]

feature3_train, feature3_test, winnings_train, winnings_test = train_test_split(feature3, winnings, train_size=0.8)

model = LinearRegression()
model.fit(feature3_train, winnings_train)
print('Predicting winnings with BreakPointsOpportunities:', model.score(feature3_test, winnings_test))

prediction3 = model.predict(feature3_test)
plt.scatter(winnings_test, prediction3, alpha=0.4)
plt.xlabel('Actual Winnings', fontsize=12)
plt.ylabel('Predicted Winnings', fontsize=12)
plt.title('Actual Winnings vs Predicted Winnings using BreakPoints Opportunities Feature')
plt.show()
# Out:
# Predicting winnings with BreakPointsOpportunities: 0.8068682676082389

# %%
feature4 = df[['Aces']]

winnings = df[['Winnings']]

feature4_train, feature4_test, winnings_train, winnings_test = train_test_split(feature4, winnings, train_size=0.8)

model = LinearRegression()
model.fit(feature4_train, winnings_train)
print('Predicting winnings with Aces:', model.score(feature4_test, winnings_test))

prediction4 = model.predict(feature4_test)
plt.scatter(winnings_test, prediction4, alpha=0.4)
plt.xlabel('Actual Winnings', fontsize=12)
plt.ylabel('Predicted Winnings', fontsize=12)
plt.title('Actual Winnings vs Predicted Winnings using Aces Feature')
plt.show()
# Out:
# Predicting winnings with Aces: 0.6826559282359583

# %% [markdown]
# ## multiple feature linear regressions

# %%
features1and2 = df[['BreakPointsConverted', 'FirstServePointsWon']]
winnings = df[['Winnings']]

features1and2_train, features1and2_test, winnings_train, winnings_test = train_test_split(features1and2, winnings, train_size= 0.8)

model = LinearRegression()
model.fit(features1and2, winnings)
print('Predicting winnings with FirstServe and FirstServePointsWon:', model.score(features1and2_test, winnings_test))

two_features_prediction = model.predict(features1and2_test)

plt.scatter(winnings_test, two_features_prediction, alpha=0.4)
plt.xlabel('Actual Winnings', fontsize=12)
plt.ylabel('Predicted Winnings', fontsize=12)
plt.title('Actual Winnings vs Predicted Winnings using BreakPointsConverted and FirstServePointsWon Feature')
plt.show()
# Out:
# Predicting winnings with FirstServe and FirstServePointsWon: 0.1559135542343687

# %%
features3and4 = df[['BreakPointsOpportunities', 'Aces']]
winnings = df[['Winnings']]

features3and4_train, features3and4_test, winnings_train, winnings_test = train_test_split(features3and4, winnings, train_size= 0.8)

model = LinearRegression()
model.fit(features3and4, winnings)
print('Predicting winnings with FirstServe and FirstServePointsWon:', model.score(features3and4_test, winnings_test))

two_features_prediction2 = model.predict(features3and4_test)

plt.scatter(winnings_test, two_features_prediction2, alpha=0.4)
plt.xlabel('Actual Winnings', fontsize=12)
plt.ylabel('Predicted Winnings', fontsize=12)
plt.title('Actual Winnings vs Predicted Winnings using BreakPointsOpportunities and Aces Feature')
plt.show()
# Out:
# Predicting winnings with FirstServe and FirstServePointsWon: 0.8227477297722542
